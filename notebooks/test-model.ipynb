# %%
import joblib

model = joblib.load('../model/log_reg_pipeline.joblib')

# %%
import pandas as pd


example_customer = pd.DataFrame({
    "gender": ["Male"],
    "SeniorCitizen": ["Yes"],
    "Partner": ["Yes"],
    "Dependents": ["Yes"],
    "tenure": [10],
    "PhoneService": ["Yes"],
    "MultipleLines": ["Yes"],
    "InternetService": ["Fiber optic"],
    "OnlineSecurity": ["No"],
    "OnlineBackup": ["No"],
    "DeviceProtection": ["Yes"],
    "TechSupport": ["No"],
    "StreamingTV": ["Yes"],
    "StreamingMovies": ["Yes"],
    "Contract": ["Two year"],
    "PaperlessBilling": ["Yes"],
    "PaymentMethod": ["Electronic check"],
    "MonthlyCharges": [80.0],
    "TotalCharges": [800.0]
})

# %%
result = model.predict(example_customer)

# %%
if result.item() == 1:
    print('Yes')
else:
    print('No')
# Out:
# Yes
